# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
characters = pd.read_csv('/content/drive/MyDrive/DataVisualization/characters_stats.csv')

# %%
characters.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
characters['Alignment'].value_counts()
# Out:
# Alignment
# good       432
# bad        165
# neutral     11
# Name: count, dtype: int64

# %%
good=characters[characters["Alignment"]=="good"]
good.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
good.sort_values(by=["Speed"],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 232        Flash IV      good            63        10    100          32
# 295         Impulse      good            50        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 333          Krypto      good             9        80    100          90
# 85       Black Bolt      good            75        67    100          84
#
#      Power  Combat  Total
# 232     59      48    312
# 295     63      60    343
# 304     70      30    348
# 333     72      40    391
# 85     100      56    482

# %%
max_speed_good = good[good['Speed']==100]
max_speed_good
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 85       Black Bolt      good            75        67    100          84
# 229         Flash I      good            63        10    100          50
# 230        Flash II      good            63        10    100          60
# 231       Flash III      good            63        10    100          60
# 232        Flash IV      good            63        10    100          32
# 295         Impulse      good            50        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 333          Krypto      good             9        80    100          90
# 418            Nova      good            38        60    100         100
# 447     Quicksilver      good            63        28    100          60
# 525        Stardust      good            88        85    100         110
# 537        Superman      good           100       100    100         100
#
# ...

# %%
min_speed_good = good[good['Speed']==1]
min_speed_good
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 7        Adam Strange      good             1         1      1           1
# 8           Agent  13      good             1         1      1           1
# 13       Alex Woolsly      good             1         1      1           1
# 15   Allan Quatermain      good             1         1      1           1
# 18     Ando Masahashi      good             1         1      1           1
# ..                ...       ...           ...       ...    ...         ...
# 580            Vulcan      good             1         1      1           1
# 584           Warbird      good             1         1      1           1
# 591       White Queen      good             1         1      1           1
# 595           Wiz Kid      good             1         1      1           1
# 601            Wondra      good             1         1      1           1
#
#      Power  Combat  Total
# 7        0       1      5
# ...

# %%
good.sort_values(by=["Power"],ascending=False).head()
# Out:
#             Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 589      Watcher      good           100        80     67          89    100
# 583  War Machine      good            63        80     63         100    100
# 547    Thor Girl      good            75        83     70          84    100
# 546         Thor      good            69       100     92         100    100
# 525     Stardust      good            88        85    100         110    100
#
#      Combat  Total
# 589      56    492
# 583      85    491
# 547      70    482
# 546      85    546
# 525      85    568

# %%
good_max_power = good.sort_values(by=['Total'],ascending=False)
good_max_power
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
# ..                 ...       ...           ...       ...    ...         ...
# 89       Black Goliath      good             1         1      1           1
# 559      Tracy Strauss      good             1         1      1           1
# 566           Vagabond      good             1         1      1           1
# 33             Arachne      good             1         1      1           1
# 591        White Queen      good             1         1      1           1
#
#      Power  Combat  Total
# 361    100      85    581
# ...

# %%
good_max_intelligence = good.sort_values(by=['Intelligence'],ascending=False)
good_max_intelligence
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 589       Watcher      good           100        80     67          89    100
# 578        Vision      good           100        72     54          95     76
# 537      Superman      good           100       100    100         100     94
# 24        Ant-Man      good           100        10     23          28     32
# 440   Professor X      good           100         8     12          14     90
# ..            ...       ...           ...       ...    ...         ...    ...
# 64           Beak      good             1         1      1           1      0
# 584       Warbird      good             1         1      1           1      0
# 8       Agent  13      good             1         1      1           1      0
# 7    Adam Strange      good             1         1      1           1      0
# 591   White Queen      good             1         1      1           1      0
#
#      Combat  Total
# ...

# %%
plt.figure(figsize=(8,5))
plt.bar(list(good_max_power['Name'])[0:5],list(good_max_power['Total'])[0:5],color="g")
plt.show()
plt.figure(figsize=(8,5))
plt.bar(list(good_max_intelligence['Name'])[0:5],list(good_max_intelligence['Intelligence'])[0:5],color="g")
plt.show()

# %%
characters['Alignment'].value_counts()
# Out:
# Alignment
# good       432
# bad        165
# neutral     11
# Name: count, dtype: int64

# %%
bad=characters[characters["Alignment"]=="bad"]
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
bad.sort_values(by=["Speed"],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 610            Zoom       bad            50        10    100          28
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 610     72      28    288
# 242     94      95    579

# %%
max_speed_bad = bad[bad['Speed']==100]
max_speed_bad
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 610     72      28    288

# %%
min_speed_bad = bad[bad['Speed']==1]
min_speed_bad
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 17               Ammo       bad             1         1      1           1
# 21             Angela       bad             1         1      1           1
# 27         Anti-Spawn       bad             1         1      1           1
# 67             Beetle       bad             1         1      1           1
# 75      Billy Kincaid       bad             1         1      1           1
# 78           Bird-Man       bad             1         1      1           1
# 79        Bird-Man II       bad             1         1      1           1
# 83       Black Abbott       bad             1         1      1           1
# 103          Blizzard       bad             1         1      1           1
# 104        Blizzard I       bad             1         1      1           1
# 109       Bloodwraith       bad             1         1      1           1
# ...

# %%
bad.sort_values(by=["Power"],ascending=False).head()
# Out:
#             Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 5        Abraxas       bad            88       100     83          99    100
# 16         Amazo       bad            75       100    100         100    100
# 11    Air-Walker       bad            50        85    100          85    100
# 29    Apocalypse       bad           100       100     33         100    100
# 26  Anti-Monitor       bad            88        90     38          90    100
#
#     Combat  Total
# 5       56    526
# 16     100    575
# 11      40    460
# 29      60    493
# 26      90    496

# %%
bad_max_power = bad.sort_values(by=['Total'],ascending=False)
bad_max_power
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 242      General Zod       bad            94       100     96         100
# 535   Superboy-Prime       bad            94       100    100         100
# 16             Amazo       bad            75       100    100         100
# 203         Dormammu       bad            88        95     83         100
# 201         Doomsday       bad            88        80     67         120
# ..               ...       ...           ...       ...    ...         ...
# 521  Spider-Woman IV       bad             1         1      1           1
# 515   Spider-Carnage       bad             1         1      1           1
# 576         Violator       bad             1         1      1           1
# 590        Weapon XI       bad             1         1      1           1
# 605      Yellow Claw       bad             1         1      1           1
#
#      Power  Combat  Total
# 242     94      95    579
# ...

# %%
plt.figure(figsize=(8,5))
plt.bar(list(bad_max_power['Name'])[0:5],list(bad_max_power['Total'])[0:5],color="r")
plt.show()

# %%
plt.figure(figsize=(5,7))
plt.hist(good['Speed'],bins=50)
plt.title("Distribution of Speed")
plt.xlabel("Speed")
plt.show()

# %%
plt.figure(figsize=(5,7))
plt.hist(bad['Speed'], bins = 50)
plt.title("Distribution of Speed")
plt.xlabel("Speed")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.hist(good['Combat'], bins= 50)
plt.title("Distribution of Combat")
plt.xlabel("Combat")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.hist(bad['Combat'], bins= 50)
plt.title("Distribution of Combat")
plt.xlabel("Combat")
plt.show()

# %% [markdown]
# ### Ques:  Let's take any character and checkout his different skills on pie chart to find out which one his major skill and weak skills.

# %%
antmanskills = good[good['Name']=='Ant-Man']
antmanskills
# Out:
#        Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 24  Ant-Man      good           100        10     23          28     32
#
#     Combat  Total
# 24      32    225

# %%
# For making pie chart we need values in form of list. So we'll convert them in list.
ant_list=list(antmanskills.values)

print(ant_list) # Here we can see that the list also have 'Ant-Man' and 'good' written. We also don't want total. We don't want these so we'll do list slicing.

ant_list = ant_list[0][2:8] # We sliced the ant_list and put the values back in ant_list
print(ant_list)
# Out:
# [array(['Ant-Man', 'good', 100, 10, 23, 28, 32, 32, 225], dtype=object)]
# [100 10 23 28 32 32]

# %%
labels = list(antmanskills.columns.values) # Here it will contain all the labels of antman. We will slice them too.
labels_name=labels[2:8]
plt.pie(ant_list, labels=labels_name) # Here we have first put the list with numbers and then we have put the labels name.
plt.show()
